# %%
# !pip install selenium

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time
from PIL import Image
import io
import requests
from selenium.common.exceptions import ElementClickInterceptedException

# %% [markdown]
# # Question4

# %%
#connecting to webdriver
driver=webdriver.Chrome(r'C:\Users\GOD\Desktop\chromedriver.exe')

# %%
url='http://www.flipkart.com/'
driver.get(url)

# %%
#closing  pop up
popup=driver.find_element_by_xpath('/html/body/div[2]/div/div/button')
popup.click()

# %%
#finding the web element using the search bar using class id
search_product = driver.find_element_by_class_name("_3704LK")
search_product.send_keys("iphone")

# %%
#clicking the search button
search_button = driver.find_element_by_class_name('L0Z3Pu')
search_button.click()

# %%
#extracting brand name
brand_name=[]
try:
    brand=driver.find_elements_by_xpath('//div[@class="_4rR01T"]')
    for i in brand:
        brand_name.append(i.text)
except:
    brand_name.appenb('-')

# %%
#extracting rom name
rom_size=[]
try:
    rom=driver.find_elements_by_xpath('//ul[@class="_1xgFaf"]/li[1]')
    for i in rom:
        rom_size.append(i.text)
except:
    rom_size.append('-')

# %%
#extracting display size
display_size=[]
try:
    display=driver.find_elements_by_xpath('//ul[@class="_1xgFaf"]/li[2]')
    for i in display:
        display_size.append(i.text)
except:
    display_size.append('-')

# %%
#extracting camera specs
camera=[]
try:
    cam=driver.find_elements_by_xpath('//ul[@class="_1xgFaf"]/li[3]')
    for i in cam:
        camera.append(i.text)
except:
    camera.append('-')

# %%
#extracting processor specs
processor=[]
try:
    chip=driver.find_elements_by_xpath('//ul[@class="_1xgFaf"]/li[4]')
    for i in chip:
        processor.append(i.text)
except:
    processor.append('-')

# %%
#extracting price
price=[]
try:
    cost=driver.find_elements_by_xpath('//div[@class="_30jeq3 _1_WHN1"]')
    for i in cost:
        price.append(i.text)
except:
    price.append('-')

# %%
#Getting the links of all products

links=[]
productlinks=driver.find_elements_by_xpath("//div[@class='_1AtVbE col-12-12']/div[1]/div[1]/div[1]/a[1]")

for i in productlinks:
    links.append(i.get_attribute('href'))
# Out:
# 24

# %%
flipkart=pd.DataFrame()
flipkart['Brand name']=brand_name
flipkart['Rom Size']=rom_size
flipkart['Display Size']=display_size
flipkart['Camera Specs']= camera
flipkart['Processor Specs']=processor
flipkart['Price']= price
flipkart['Product Link']= links
flipkart.to_csv('flipkart.csv')
flipkart
# Out:
#                                 Brand name    Rom Size  \
# 0           APPLE iPhone SE (Black, 64 GB)   64 GB ROM
# 1             APPLE iPhone SE (Red, 64 GB)   64 GB ROM
# 2           APPLE iPhone SE (White, 64 GB)   64 GB ROM
# 3           APPLE iPhone 11 (Green, 64 GB)   64 GB ROM
# 4          APPLE iPhone SE (White, 128 GB)  128 GB ROM
# 5       APPLE iPhone 13 (Midnight, 128 GB)  128 GB ROM
# 6      APPLE iPhone 13 (Starlight, 128 GB)  128 GB ROM
# 7            APPLE iPhone SE (Red, 128 GB)  128 GB ROM
# 8      APPLE iPhone 12 Mini (Black, 64 GB)   64 GB ROM
# 9          APPLE iPhone SE (Black, 128 GB)  128 GB ROM
# 10    APPLE iPhone 12 Mini (Purple, 64 GB)   64 GB ROM
# 11          APPLE iPhone 11 (White, 64 GB)   64 GB ROM
# 12      APPLE iPhone 13 (Midnight, 256 GB)  256 GB ROM
# 13         APPLE iPhone XR (White, 128 GB)  128 GB ROM
# 14     APPLE iPhone 12 Mini (White, 64 GB)   64 GB ROM
# 15         APPLE iPhone 11 (Black, 128 GB)  128 GB ROM
# ...

# %% [markdown]
# # Question 5

# %%
#Taking the input
city=input("Enter the city to get its coordinats:")
# Out:
# Enter the city to get its coordinats:chennai

# %%
#initialising the driver
driver=webdriver.Chrome(r"C:\Users\GOD\Desktop\chromedriver.exe")
driver.get('https://www.google.com/maps')

# %%
#Finding the searchbar and sending keys into it
search_bar=driver.find_element_by_name("q")
search_bar.send_keys(city)

# %%
#finding the search button and clicking
search_btn=driver.find_element_by_id('searchbox-searchbutton')
search_btn.click()
time.sleep(5)

# %%
#Getting current url
cityurl=driver.current_url
urls=cityurl.split('@')
loc=urls[1].split(',')
coordinates=loc[:2]

# %%
#Printing the coordinates of the city
print(f'co-ordinates of {city}:',coordinates)
# Out:
# co-ordinates of chennai: ['10.7828364', '78.2885026']

# %% [markdown]
# # Question 6

# %%
from selenium.webdriver.chrome.options import Options
options = Options()
options.add_argument("--disable-notifications")
from selenium.webdriver.support.ui import Select

# %%
#Initialising the driver
driver=webdriver.Chrome(r"C:\Users\GOD\Desktop\chromedriver.exe")
driver.get('https://trak.in/')
time.sleep(5)

# %%
search=driver.find_element_by_xpath('//li[@class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page better-anim-fade menu-item-51510"]/a[1]')
link=search.get_attribute('href')
time.sleep(10)

# %%
driver.get(link)

# %%
lis=['tablepress-50_length','tablepress-49_length','tablepress-48_length']
for i in lis:
    select = Select(driver.find_element_by_name(i))
    select.select_by_visible_text('50')

# %%
date=[]
name=[]
vertical=[]
sub=[]
city=[]
investor=[]
invest=[]
amount=[]

# %%
investment=['//table[@class="tablepress tablepress-id-54 dataTable no-footer"]/tbody/tr/td[9]',
     '//table[@class="tablepress tablepress-id-55 dataTable no-footer"]/tbody/tr/td[9]',
     '//table[@class="tablepress tablepress-id-56 dataTable no-footer"]/tbody/tr/td[9]']
for i in investment:
    investments=driver.find_elements_by_xpath(i)
    for j in investments:
        amount.append(j.text)

# %%
invest_type=['//table[@class="tablepress tablepress-id-54 dataTable no-footer"]/tbody/tr/td[8]',
     '//table[@class="tablepress tablepress-id-55 dataTable no-footer"]/tbody/tr/td[8]',
     '//table[@class="tablepress tablepress-id-56 dataTable no-footer"]/tbody/tr/td[8]']
for i in invest_type:
    invests=driver.find_elements_by_xpath(i)
    for j in invests:
        invest.append(j.text)

# %%
investor_names=['//table[@class="tablepress tablepress-id-54 dataTable no-footer"]/tbody/tr/td[7]',
     '//table[@class="tablepress tablepress-id-55 dataTable no-footer"]/tbody/tr/td[7]',
     '//table[@class="tablepress tablepress-id-56 dataTable no-footer"]/tbody/tr/td[7]']
for i in investor_names:
    investors=driver.find_elements_by_xpath(i)
    for j in investors:
        investor.append(j.text)

# %%
ids=['//table[@class="tablepress tablepress-id-54 dataTable no-footer"]/tbody/tr/td[2]',
     '//table[@class="tablepress tablepress-id-55 dataTable no-footer"]/tbody/tr/td[2]',
     '//table[@class="tablepress tablepress-id-56 dataTable no-footer"]/tbody/tr/td[2]']
for i in ids:
    dates=driver.find_elements_by_xpath(i)
    for dts in dates:
        date.append(dts.text)

# %%
names=['//table[@class="tablepress tablepress-id-54 dataTable no-footer"]/tbody/tr/td[3]',
     '//table[@class="tablepress tablepress-id-55 dataTable no-footer"]/tbody/tr/td[3]',
     '//table[@class="tablepress tablepress-id-56 dataTable no-footer"]/tbody/tr/td[3]']
for i in names:
    company=driver.find_elements_by_xpath(i)
    for j in company:
        name.append(j.text)

# %%
industries=['//table[@class="tablepress tablepress-id-54 dataTable no-footer"]/tbody/tr/td[4]',
     '//table[@class="tablepress tablepress-id-55 dataTable no-footer"]/tbody/tr/td[4]',
     '//table[@class="tablepress tablepress-id-56 dataTable no-footer"]/tbody/tr/td[4]']
for i in industries:
    industry=driver.find_elements_by_xpath(i)
    for j in industry:
        vertical.append(j.text)

# %%
verticals=['//table[@class="tablepress tablepress-id-54 dataTable no-footer"]/tbody/tr/td[5]',
     '//table[@class="tablepress tablepress-id-55 dataTable no-footer"]/tbody/tr/td[5]',
     '//table[@class="tablepress tablepress-id-56 dataTable no-footer"]/tbody/tr/td[5]']
for i in verticals:
    verticals_sub=driver.find_elements_by_xpath(i)
    for j in verticals_sub:
        sub.append(j.text)

# %%
locations=['//table[@class="tablepress tablepress-id-54 dataTable no-footer"]/tbody/tr/td[6]',
     '//table[@class="tablepress tablepress-id-55 dataTable no-footer"]/tbody/tr/td[6]',
     '//table[@class="tablepress tablepress-id-56 dataTable no-footer"]/tbody/tr/td[6]']
for i in locations:
    location=driver.find_elements_by_xpath(i)
    for j in location:
        city.append(j.text)

# %%
fundings=pd.DataFrame({})
fundings['Dates']=date
fundings['Startup']=name
fundings['Industry']=vertical
fundings['Sub-Domain']=sub
fundings['City']=city
fundings['Investor']=investor
fundings['Investment Type']=invest
fundings['Investment']=amount
fundings
# Out:
#          Dates                 Startup                Industry  \
# 0   15/01/2021         Digit Insurance      Financial Services
# 1   28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 2   19/01/2021                  DeHaat        AgriTech Startup
# 3   19/01/2021               Darwinbox                    SaaS
# 4   18/01/2021                   mfine     Health Tech Startup
# 5   18/01/2021                   Udayy                  EdTech
# 6   11/01/2021           True Elements            Food Startup
# 7   13/01/2021                   Saveo          B2B E-commerce
# 8   11/02/2021                Doubtnut                Edu Tech
# 9   22/02/2021                  Zomato             Hospitality
# 10  19/02/2021               Fingerlix             Hospitality
# 11  17/02/2021                   Zolve                 FinTech
# 12  15/02/2021               KreditBee                 Finance
# 13  12/02/2021               Pepperfry              E-commerce
# ...

# %% [markdown]
# # Question 7

# %%
#Initialising the driver
driver=webdriver.Chrome(r"C:\Users\GOD\Desktop\chromedriver.exe")
driver.get('https://www.digit.in/')
time.sleep(5)

# %%
#Finding and getting link of the element laptop in home page
lptop=driver.find_element_by_xpath('/html/body/div[1]/div/div[4]/ul/li[3]/a')
link=lptop.get_attribute('href')
driver.get(link)
time.sleep(5)

# %%
#Getting the link of best laptops
best=driver.find_element_by_xpath('/html/body/div[6]/div/div[2]/div[2]/ul/li[10]/a')
link=best.get_attribute('href')
driver.get(link)
time.sleep(10)

# %%
#Empty lists to store fetched details
title=[]
os=[]
display=[]
processor=[]
memory=[]
weight=[]
dimension=[]
gp=[]
price=[]
seller=[]
description=[]
time.sleep(3)

# %%
#scrapping tile
comp_name=driver.find_elements_by_xpath('//div[@class="Top10-Seller"]/table[1]/tbody/tr/td[1]')
for i in comp_name:
    title.append(i.text)

# %%
#scrapping os
opsys=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[3]/td[3]')
for i in opsys:
    os.append(i.text)

# %%
#scrapping display
dis= driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[4]/td[3]')
for i in dis:
    display.append(i.text)

# %%
#scrapping processor
pros=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[5]/td[3]')
for i in pros:
    processor.append(i.text)

# %%
#dimension
dimen=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for i in dimen:
    dimension.append(i.text)

# %%
#weight
wgt=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
for i in wgt:
    weight.append(i.text)

# %%
#memory
mem=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]')
for i in mem:
    memory.append(i.text)

# %%
#graphics processor
graphics=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[9]/td[3]')
for i in graphics:
    gp.append(i.text)

# %%
#seller
sel=driver.find_elements_by_xpath('//td[@class="smmerchant"]')
for i in sel:
    seller.append(i.text)

# %%
#price
cost=driver.find_elements_by_xpath('//td[@class="smprice"]')
for i in cost:
    price.append(i.text)

# %%
#description
des=driver.find_elements_by_xpath('//div[@class="Section-center"]/p')
for i in des:
    description.append(i.text)

# %%
digit=pd.DataFrame()
digit['title']=title
digit['os']=os
digit['display']=display
digit['processor']=processor
digit['memory']=memory
digit['weight']=weight
digit['dimension']=dimension
digit['gp']=gp
digit['price']=price
digit['seller']=seller
digit['description']=description
driver.close()
digit
# Out:
#                          title               os              display  \
# 0                 HP Victus 16       Windows 10  16.1" (1920 x 1200)
# 1                   HP Omen 15  Windows 10 Home  15.6" (1920 x 1080)
# 2                 Acer Nitro 5       Windows 10  15.6" (1920 x 1080)
# 3              MSI Stealth 15M       Windows 10  15.6" (1920 x 1080)
# 4       ASUS ROG Strix Scar 15       Windows 10  15.6" (2560 x 1440)
# 5       ASUS ROG Strix Scar 15  Windows 10 Home  15.6" (1920 x 1080)
# 6            ASUS ZEPHYRUS G14  Windows 10 Home    14" (1920 x 1080)
# 7             Lenovo Legion 5i   Windows 10 Pro  15.6" (1920 x 1080)
# 8     ASUS ROG ZEPHYRUS DUO 15       Windows 10  15.6" (3840 x 1100)
# 9  Acer Aspire 7 gaming laptop  Windows 10 Home  15.6" (1920 x 1080)
#
#                                     processor                   memory weight  \
# 0          5th Gen AMD Ryzen 7 5800H | 3.2GHz  512 GB SSD/16 GBGB DDR4   2.48
# ...

# %% [markdown]
# # Question 8

# %%
#Initialising the driver
driver=webdriver.Chrome(r"C:\Users\GOD\Desktop\chromedriver.exe")
driver.get('https://www.forbes.com/billionaires/')
time.sleep(3)

# %%
name=[]
rank=[]
worth=[]
country=[]
source=[]
tech=[]

# %%
#scrapping name
try:
    names=driver.find_elements_by_xpath('//div[@class="personName"]')
    for i in names:
        name.append(i.text)
except:
    name.append('-')
print('Name:',len(name))
# Out:
# Name: 200

# %%
#scrapping rank
try:
    ranks=driver.find_elements_by_xpath('//div[@class="rank"]')
    for i in ranks:
        rank.append(i.text)
except:
    rank.append('-')
print('Rank:',len(rank))
# Out:
# Rank: 200

# %%
#scrapping net worth
try:
    networth=driver.find_elements_by_xpath('//div[@class="netWorth"]')
    for i in networth:
        worth.append(i.text)
except:
    worth.append('-')
print('Worth:',len(worth))
# Out:
# Worth: 200

# %%
#scrapping citizenship
try:
    citizenship=driver.find_elements_by_xpath('//div[@class="countryOfCitizenship"]')
    for i in citizenship:
        country.append(i.text)
except:
    country.append('-')
print('Country:',len(country))
# Out:
# Country: 200

# %%
#scrapping source

try:
    sources=driver.find_elements_by_xpath('//div[@class="source"]')
    for i in sources:
        source.append(i.text)
except:
    source.append('-')
print('Source:',len(source))
# Out:
# Source: 200

# %%
#scrapping industry 
try:
    industry=driver.find_elements_by_xpath('//div[@class="category"]')
    for i in industry:
        tech.append(i.text)
except:
    tech.append('-')
print('industry:',len(tech))
# Out:
# industry: 200

# %%
#collecting in dataframe
#DataFrame
forbes=pd.DataFrame({})
forbes['Rank']=rank
forbes['Name']=name
forbes['Worth']=worth
forbes['Nationality']=country
forbes['Source']=source
forbes['Industry']=tech
driver.close()
forbes
# Out:
#      Rank                      Name    Worth    Nationality  \
# 0      1.                Jeff Bezos   $177 B  United States
# 1      2.                 Elon Musk   $151 B  United States
# 2      3.  Bernard Arnault & family   $150 B         France
# 3      4.                Bill Gates   $124 B  United States
# 4      5.           Mark Zuckerberg    $97 B  United States
# ..    ...                       ...      ...            ...
# 195  195.           Harry Triguboff  $11.2 B      Australia
# 196  197.     Leonid Fedun & family  $11.1 B         Russia
# 197  197.                 Eyal Ofer  $11.1 B         Israel
# 198  197.              Evan Spiegel  $11.1 B  United States
# 199  200.     Luis Carlos Sarmiento    $11 B       Colombia
#
#                     Source               Industry
# 0                   Amazon             Technology
# 1            Tesla, SpaceX             Automotive
# 2                     LVMH       Fashion & Retail
# ...

# %% [markdown]
# # Question 10

# %%
driver=webdriver.Chrome(r"C:\Users\GOD\Desktop\chromedriver.exe")
driver.get('https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2021-10-25&to=2021-10-28&guests=2&page=1')
time.sleep(5)

# %%
hostel=[]
dist=[]
rating=[]
overallrev=[]

# %%
#scrapping hostel names 

hostel_name=driver.find_elements_by_xpath('//div[@class="property-card"]/div[2]/a[1]/div[1]/h2')
for i in hostel_name:
    hostel.append(i.text)
hostels=driver.find_elements_by_xpath('//h2[@class="title title-6"]/a')
for i in hostels:
    hostel.append(i.text)

# %%
#scrapping distance from city centre

distance=driver.find_elements_by_xpath('//div[@class="subtitle body-3"]')
for i in distance:
    dist.append(i.text)

# %%
#scrapping ratings

ratings=driver.find_elements_by_xpath('//div[@class="score orange small"]')
for i in ratings:
    rating.append(i.text)
try:
    other_ratings=driver.find_elements_by_xpath('//div[@class="rating rating-summary-container big"]/div[1]')
    for i in other_ratings:
        rating.append(i.text)
except:
    rating.append('_')

# %%
#scrapping Overall reviews

overall_reviews=driver.find_elements_by_xpath('//div[@class="keyword"]')
for i in overall_reviews:
    overallrev.append(i.text)

# %%
hostels=pd.DataFrame({})
hostels['Name']=hostel
hostels['Distance']=dist
hostels['Ratings']=rating
hostels['Overall Reviews']=overallrev
hostels
# Out:
#                                        Name  \
# 0                  St Christopher's Village
# 1                  St Christopher's Village
# 2         Safestay London Elephant & Castle
# 3                   Smart Camden Inn Hostel
# 4                          Generator London
# 5                             Pickwick Hall
# 6                           Astor Hyde Park
# 7                      Urbany Hostel London
# 8                        London Backpackers
# 9               Smart Russell Square Hostel
# 10              Smart Hyde Park View Hostel
# 11                  Prime Backpackers Angel
# 12  Safestay London Kensington Holland Park
# 13     St Christopher's Inn - London Bridge
# 14                 YHA London Oxford Street
# 15                 Barmy Badger Backpackers
# 16          Wombat's The City Hostel London
# 17                       Strand Continental
# 18               Smart Hyde Park Inn Hostel
# 19                     New Cross Inn Hostel
# ...

# %% [markdown]
# # Question 9

# %%
#Initialising the driver
driver=webdriver.Chrome(r"C:\Users\GOD\Desktop\chromedriver.exe")
driver.get('https://www.youtube.com/')
time.sleep(5)

# %%
#giving input in the search bar

search_bar=driver.find_element_by_xpath('/html/body/ytd-app/div/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/form/div[1]/div[1]/input')
search_bar.send_keys('australian open final 2018')

# %%
#clicking the search bar 

search_button=driver.find_element_by_xpath('/html/body/ytd-app/div/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/button/yt-icon')
search_button.click()

# %%
#choosing a video to scrap

video=driver.find_element_by_xpath('/html/body/ytd-app/div/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-video-renderer[4]/div[1]/div/div[1]/div/h3/a/yt-formatted-string')
video.click()

# %% [markdown]
# # Question 1 &2

# %%
#Taking the input from user 
product_input=input("Enter the item you want to find: ")
# Out:
# Enter the item you want to find: iphone

# %%
#Initialising the driver
driver=webdriver.Chrome(r"C:\Users\GOD\Desktop\chromedriver.exe")
driver.get('https://www.amezon.in/')
time.sleep(5)

# %%
#finding the search bar 
search_bar=driver.find_element_by_id('twotabsearchtextbox')
search_bar.send_keys(product_input)

# %%
#clicking the search button 
search_button=driver.find_element_by_id("nav-search-submit-button")
search_button.click()

# %%
#getting the brand name 
brand=[]

try:
    brand_name=driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
    for i in brand_name[]:
        brand.append(i.text)

except:
    brand.append('-')
len(brand)
# Out:
# 18

# %%
#getting the price

price =[]
try:
    cost=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
    for i in cost:
        price.append(i.text)

except:
    price.append('-')
len(price)
# Out:
# 18

# %%
#getting the delivery date

ddate =[]
try:
    date=driver.find_elements_by_xpath("//span[@class='a-color-base a-text-bold']")
    for i in date:
        ddate.append(i.text)

except:
    ddate.append('-')
len(ddate)
# Out:
# 18

# %%
mobile=pd.DataFrame()
mobile['url']=urls
mobile['brand name']=brand
mobile['price']=price
mobile
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-fc6bb097a08f> in <module>
#       1 mobile=pd.DataFrame({})
#       2 mobile['url']=urls
# ----> 3 mobile['brand name']=brand
#       4 mobile['price']=price
#       5 mobile
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ...
